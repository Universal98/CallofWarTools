# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
def make_markdown_table(array):
    markdown = str("| ")

    for e in array[0]:
        to_add = " " + str(e) + str(" |")
        markdown += to_add
    markdown += "\n"

    markdown += '|'
    for i in range(len(array[0])):
        markdown += str("-------------- | ")
    markdown += "\n"

    for entry in array[1:]:
        markdown += str("| ")
        for e in entry:
            to_add = str(e) + str(" | ")
            markdown += to_add
        markdown += "\n"

    return markdown + "\n"

# %%
def generateTable(times, HPs):   
    for i, j in zip(times, HPs):
        rate_hours = i/j
        HP = np.linspace(0, j, j+1)
        time_hour = np.around(i - rate_hours*HP, 3)
        time_sec = np.around(time_hour*3600, 3)

        HP_remain = ["HP Remaining"] + list(np.flip(HP))
        time_remain = ["Time Remaining"]
        for t in time_sec:
            conversion = datetime.timedelta(seconds=t)
            time_remain.append(str(conversion))

        print(make_markdown_table(np.stack((HP_remain, time_remain), axis=1)))
        del HP_remain
        del time_remain
    return

# %% [markdown]
# # Buildings

# %% [markdown]
# ## Fortifications
# | Level | Time (hours) | HP |
# | --|--| -|
# | 1 | 6 | 40 |
# | 2 | 9      | 100 |
# | 3 | 12      | 120? |
#
# ### Level 1
# |  HP Remaining | Time Remaining |
# |-------------- | -------------- |
# | 40.0 | 6:00:00 |
# | 39.0 | 5:51:00 |
# | 38.0 | 5:42:00 |
# | 37.0 | 5:33:00 |
# | 36.0 | 5:24:00 |
# | 35.0 | 5:15:00 |
# | 34.0 | 5:06:00 |
# | 33.0 | 4:57:00 |
# | 32.0 | 4:48:00 |
# | 31.0 | 4:39:00 |
# | 30.0 | 4:30:00 |
# | 29.0 | 4:21:00 |
# | 28.0 | 4:12:00 |
# | 27.0 | 4:03:00 |
# | 26.0 | 3:54:00 |
# | 25.0 | 3:45:00 |
# | 24.0 | 3:36:00 |
# | 23.0 | 3:27:00 |
# | 22.0 | 3:18:00 |
# | 21.0 | 3:09:00 |
# | 20.0 | 3:00:00 |
# | 19.0 | 2:51:00 |
# | 18.0 | 2:42:00 |
# | 17.0 | 2:33:00 |
# | 16.0 | 2:24:00 |
# | 15.0 | 2:15:00 |
# | 14.0 | 2:06:00 |
# | 13.0 | 1:57:00 |
# | 12.0 | 1:48:00 |
# | 11.0 | 1:39:00 |
# | 10.0 | 1:30:00 |
# | 9.0 | 1:21:00 |
# | 8.0 | 1:12:00 |
# | 7.0 | 1:03:00 |
# | 6.0 | 0:54:00 |
# | 5.0 | 0:45:00 |
# | 4.0 | 0:36:00 |
# | 3.0 | 0:27:00 |
# | 2.0 | 0:18:00 |
# | 1.0 | 0:09:00 |
# | 0.0 | 0:00:00 |
#
# ### Level 2
# |  HP Remaining | Time Remaining |
# |-------------- | -------------- |
# | 100.0 | 9:00:00 |
# | 99.0 | 8:54:36 |
# | 98.0 | 8:49:12 |
# | 97.0 | 8:43:48 |
# | 96.0 | 8:38:24 |
# | 95.0 | 8:33:00 |
# | 94.0 | 8:27:36 |
# | 93.0 | 8:22:12 |
# | 92.0 | 8:16:48 |
# | 3.0 | 0:16:12 |
# | 2.0 | 0:10:48 |
# | 1.0 | 0:05:24 |
# | 0.0 | 0:00:00 |
#
# ### Level 3
# |  HP Remaining | Time Remaining |
# |-------------- | -------------- |
# | 120.0 | 12:00:00 |
# | 119.0 | 11:54:00 |
# | 118.0 | 11:48:00 |
# | 117.0 | 11:42:00 |
# | 116.0 | 11:36:00 |
# | 115.0 | 11:30:00 |
# | 114.0 | 11:24:00 |
# | 113.0 | 11:18:00 |
# | 112.0 | 11:12:00 |
# | 111.0 | 11:06:00 |
# | 110.0 | 11:00:00 |
# | 109.0 | 10:54:00 |
# | 108.0 | 10:48:00 |
# | 107.0 | 10:42:00 |
# | 106.0 | 10:36:00 |
# | 105.0 | 10:30:00 |
# | 104.0 | 10:24:00 |
# | 103.0 | 10:18:00 |
# | 102.0 | 10:12:00 |
# | 101.0 | 10:06:00 |
# | 100.0 | 10:00:00 |
# | 99.0 | 9:54:00 |
# | 98.0 | 9:48:00 |
# | 97.0 | 9:42:00 |
# | 96.0 | 9:36:00 |
# | 95.0 | 9:30:00 |
# | 94.0 | 9:24:00 |
# | 93.0 | 9:18:00 |
# | 92.0 | 9:12:00 |
# | 91.0 | 9:06:00 |
# | 90.0 | 9:00:00 |
# | 89.0 | 8:54:00 |
# | 88.0 | 8:48:00 |
# | 87.0 | 8:42:00 |
# | 86.0 | 8:36:00 |
# | 85.0 | 8:30:00 |
# | 84.0 | 8:24:00 |
# | 83.0 | 8:18:00 |
# | 82.0 | 8:12:00 |
# | 81.0 | 8:06:00 |
# | 80.0 | 8:00:00 |
# | 79.0 | 7:54:00 |
# | 78.0 | 7:48:00 |
# | 77.0 | 7:42:00 |
# | 76.0 | 7:36:00 |
# | 75.0 | 7:30:00 |
# | 74.0 | 7:24:00 |
# | 73.0 | 7:18:00 |
# | 72.0 | 7:12:00 |
# | 71.0 | 7:06:00 |
# | 70.0 | 7:00:00 |
# | 69.0 | 6:54:00 |
# | 68.0 | 6:48:00 |
# | 67.0 | 6:42:00 |
# | 66.0 | 6:36:00 |
# | 65.0 | 6:30:00 |
# | 64.0 | 6:24:00 |
# | 63.0 | 6:18:00 |
# | 62.0 | 6:12:00 |
# | 61.0 | 6:06:00 |
# | 60.0 | 6:00:00 |
# | 59.0 | 5:54:00 |
# | 58.0 | 5:48:00 |
# | 57.0 | 5:42:00 |
# | 56.0 | 5:36:00 |
# | 55.0 | 5:30:00 |
# | 54.0 | 5:24:00 |
# | 53.0 | 5:18:00 |
# | 52.0 | 5:12:00 |
# | 51.0 | 5:06:00 |
# | 50.0 | 5:00:00 |
# | 49.0 | 4:54:00 |
# | 48.0 | 4:48:00 |
# | 47.0 | 4:42:00 |
# | 46.0 | 4:36:00 |
# | 45.0 | 4:30:00 |
# | 44.0 | 4:24:00 |
# | 43.0 | 4:18:00 |
# | 42.0 | 4:12:00 |
# | 41.0 | 4:06:00 |
# | 40.0 | 4:00:00 |
# | 39.0 | 3:54:00 |
# | 38.0 | 3:48:00 |
# | 37.0 | 3:42:00 |
# | 36.0 | 3:36:00 |
# | 35.0 | 3:30:00 |
# | 34.0 | 3:24:00 |
# | 33.0 | 3:18:00 |
# | 32.0 | 3:12:00 |
# | 31.0 | 3:06:00 |
# | 30.0 | 3:00:00 |
# | 29.0 | 2:54:00 |
# | 28.0 | 2:48:00 |
# | 27.0 | 2:42:00 |
# | 26.0 | 2:36:00 |
# | 25.0 | 2:30:00 |
# | 24.0 | 2:24:00 |
# | 23.0 | 2:18:00 |
# | 22.0 | 2:12:00 |
# | 21.0 | 2:06:00 |
# | 20.0 | 2:00:00 |
# | 19.0 | 1:54:00 |
# | 18.0 | 1:48:00 |
# | 17.0 | 1:42:00 |
# | 16.0 | 1:36:00 |
# | 15.0 | 1:30:00 |
# | 14.0 | 1:24:00 |
# | 13.0 | 1:18:00 |
# | 12.0 | 1:12:00 |
# | 11.0 | 1:06:00 |
# | 10.0 | 1:00:00 |
# | 9.0 | 0:54:00 |
# | 8.0 | 0:48:00 |
# | 7.0 | 0:42:00 |
# | 6.0 | 0:36:00 |
# | 5.0 | 0:30:00 |
# | 4.0 | 0:24:00 |
# | 3.0 | 0:18:00 |
# | 2.0 | 0:12:00 |
# | 1.0 | 0:06:00 |
# | 0.0 | 0:00:00 |

# %%
fort_times = np.array([6, 9, 12]) # hours
fort_HP = np.array([40, 100, 120])

generateTable(fort_times, fort_HP)
# Out:
# |  HP Remaining | Time Remaining |
# |-------------- | -------------- |
# | 40.0 | 6:00:00 |
# | 39.0 | 5:51:00 |
# | 38.0 | 5:42:00 |
# | 37.0 | 5:33:00 |
# | 36.0 | 5:24:00 |
# | 35.0 | 5:15:00 |
# | 34.0 | 5:06:00 |
# | 33.0 | 4:57:00 |
# | 32.0 | 4:48:00 |
# | 31.0 | 4:39:00 |
# | 30.0 | 4:30:00 |
# | 29.0 | 4:21:00 |
# | 28.0 | 4:12:00 |
# | 27.0 | 4:03:00 |
# | 26.0 | 3:54:00 |
# | 25.0 | 3:45:00 |
# | 24.0 | 3:36:00 |
# | 23.0 | 3:27:00 |
# | 22.0 | 3:18:00 |
# | 21.0 | 3:09:00 |
# | 20.0 | 3:00:00 |
# | 19.0 | 2:51:00 |
# | 18.0 | 2:42:00 |
# | 17.0 | 2:33:00 |
# | 16.0 | 2:24:00 |
# | 15.0 | 2:15:00 |
# | 14.0 | 2:06:00 |
# | 13.0 | 1:57:00 |
# | 12.0 | 1:48:00 |
# | 11.0 | 1:39:00 |
# | 10.0 | 1:30:00 |
# | 9.0 | 1:21:00 |
# | 8.0 | 1:12:00 |
# | 7.0 | 1:03:00 |
# | 6.0 | 0:54:00 |
# | 5.0 | 0:45:00 |
# | 4.0 | 0:36:00 |
# | 3.0 | 0:27:00 |
# | 2.0 | 0:18:00 |
# | 1.0 | 0:09:00 |
# | 0.0 | 0:00:00 |
#
#
# |  HP Remaining | Time Remaining |
# ...
